# %% [markdown]
# # Run level 2A and 2B pipelines on MRS data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) January 9th 2017

# %% [markdown]
# This notebook demonstrates the execution of the level 2A and 2B pipelines for MRS data in Python using the jwst.pipeline classes.
#
# For a description of the pipeline classes see:
#
# http://ssb.stsci.edu/doc/jwst_git/docs/pipeline/html/description.html
#
# The file used in this notebook is a MIRISim simulation of a point source with a blackbody plus emission lnes spectrum

# %% [markdown]
# #### Imports

# %%
import os

import numpy as np
from astropy.io import fits

import matplotlib.pyplot as plt

# %% [markdown]
# #### Set input file:

# %%
# set filename
input_file = 'det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits'

# extract the basename for use in output files
input_basename = os.path.splitext(input_file)[0]

# %% [markdown]
# #### print some information about the input file

# %%
# print some info on input file
with fits.open(input_file) as hdulist:
    
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t\t\t\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band"
        print "--------------------------------------------------------------------------------------------------"
        print "%s\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (identifier,detector,nInts,nGroups,readPatt,subArr,channel,band)
        print "\n\n"
        
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band"
        print "--------------------------------------------------------------------------------------------------"
        print "MIRISim\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (detector,nInts,nGroups,readPatt,subArr,channel,band)
        print "\n\n"

    # fits extension table
    hdulist.info()
# Out:
# ID	 Detector	 nInts	 nGrps	 rdPatt	 subAr	 chan.	 band
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIFUSHORT	 3	 30	 SLOW	 FULL	 12	 SHORT
#
#
#
# Filename: det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     137   ()
#   1  SCI         ImageHDU        14   (1032, 1024, 30, 3)   float32
#   2  REFOUT      ImageHDU        14   (258, 1024, 30, 3)   float32
#   3  PIXELDQ     ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   4  PIXELDQ_DEF  BinTableHDU     17   29R x 4C   [J, J, 40A, 128A]
#   5  ASDF        ImageHDU         7   (480839910,)   uint8

# %% [markdown]
# #### show the last frame of the first integration

# %%
from jwst import datamodels
from matplotlib.colors import LogNorm

# open the input image as a jwst data model
with datamodels.open(input_file) as in_dm:
        
    # plot--------------------------------------
    # show the input ramp image and the calibrated
    # slope image. Note the user may need to adjust
    # the scale parameters of the plot
    # %matplotlib notebook
    fig, axs = plt.subplots(1, 1, figsize=(8, 8))

    # sum the groups in the first integration of the input ramp image and plot
    axs.imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
    axs.annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs.set_axis_bgcolor('black')

    plt.tight_layout()
    plt.show()
# Out:
# No handlers could be found for logger "jwst.datamodels.util"
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import SloperPipeline
print SloperPipeline.__doc__
# Out:
# The following task in the fitsblender package can be run with TEAL:
#                                   blendheaders
#
#
#     SloperPipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     dq_init, saturation, ipc, superbias, refpix, rscd, lastframe,
#     linearity, dark_current, persistence, jump detection, and ramp_fit.

# %% [markdown]
# For MIRI, the steps in order are: dq_init, saturation, ipc, linearity, RSCD, lastframe, dark_current, refpix, persistence (no-op), jump, ramp_fitting

# %% [markdown]
# #### run pipeline

# %%
SloperPipeline.call(input_file, output_file='%s_rate.fits' % input_basename)
# Out:
# 2017-02-17 11:06:20,939 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-02-17 11:06:20,941 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-02-17 11:06:20,942 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-02-17 11:06:20,944 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-02-17 11:06:20,945 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-02-17 11:06:20,947 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-02-17 11:06:20,949 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-02-17 11:06:20,951 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-02-17 11:06:20,952 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-02-17 11:06:20,954 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-02-17 11:06:20,955 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-02-17 11:06:20,957 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-02-17 11:06:20,958 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-02-17 11:06:33,504 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits'.
# 2017-02-17 11:06:38,810 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2017-02-17 11:06:44,080 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2017-02-17 11:06:49,386 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-02-17 11:06:49,387 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0037.fits'.
# 2017-02-17 11:06:54,669 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0013.fits'.
# 2017-02-17 11:06:59,955 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-02-17 11:06:59,956 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0037.fits'.
# 2017-02-17 11:07:05,254 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-02-17 11:07:13,513 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2017-02-17 11:07:18,804 - stpipe.SloperPipeline.dark_current - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0044.fits'.
# 2017-02-17 11:07:27,046 - stpipe.SloperPipeline.superbias - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2017-02-17 11:07:27,393 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits',).
# 2017-02-17 11:07:27,394 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-02-17 11:07:30,512 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2017-02-17 11:07:30,660 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2508b2e50>,).
# 2017-02-17 11:07:32,548 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2017-02-17 11:07:33,448 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-02-17 11:07:35,560 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2017-02-17 11:07:35,721 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x200652490>,).
# 2017-02-17 11:07:37,607 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2017-02-17 11:07:39,633 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-02-17 11:07:41,687 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits'.
# 2017-02-17 11:07:41,837 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2c8fba350>,).
# 2017-02-17 11:07:43,741 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits
# 2017-02-17 11:07:46,774 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-02-17 11:07:48,767 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0013.fits'.
# 2017-02-17 11:07:48,916 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2c8cfa550>,).
# 2017-02-17 11:07:50,866 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0013.fits
# 2017-02-17 11:07:52,998 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-02-17 11:07:55,014 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2017-02-17 11:07:55,184 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x20064ab10>,).
# 2017-02-17 11:07:57,081 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2017-02-17 11:09:11,169 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-02-17 11:09:11,540 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10d684950>,).
# 2017-02-17 11:09:13,058 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-02-17 11:09:15,004 - stpipe.SloperPipeline.dark_current - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0044.fits'.
# 2017-02-17 11:09:15,166 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x185a81fd0>,).
# 2017-02-17 11:09:17,118 - stpipe.SloperPipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0044.fits
# 2017-02-17 11:09:17,300 - stpipe.SloperPipeline.dark_current - INFO - Science data nints=3, ngroups=30, nframes=1, groupgap=0
# 2017-02-17 11:09:17,300 - stpipe.SloperPipeline.dark_current - INFO - Dark data nints=2, ngroups=45, nframes=1, groupgap=0
# 2017-02-17 11:09:19,501 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-02-17 11:09:21,601 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-02-17 11:09:21,780 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2c8fba450>,).
# 2017-02-17 11:09:22,559 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-02-17 11:09:22,560 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-02-17 11:09:22,560 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-02-17 11:09:22,561 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-02-17 11:09:22,562 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-02-17 11:09:22,564 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-02-17 11:09:24,342 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-02-17 11:09:26,101 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-02-17 11:09:26,613 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2c8f89e50>,).
# 2017-02-17 11:09:28,276 - stpipe.SloperPipeline.persistence - WARNING - Persistence step is currently a no-op: SKIPPING
# 2017-02-17 11:09:28,284 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-02-17 11:09:30,392 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-02-17 11:09:30,393 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0037.fits'.
# 2017-02-17 11:09:30,554 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2c8fbaf90>,).
# 2017-02-17 11:09:31,361 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-02-17 11:09:32,604 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-02-17 11:09:33,807 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0037.fits
# 2017-02-17 11:09:34,979 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-02-17 11:09:36,990 - stpipe.SloperPipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:769: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
#
# 2017-02-17 11:35:10,209 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-02-17 11:35:18,385 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-02-17 11:35:18,386 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0037.fits'.
# 2017-02-17 11:35:18,578 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10e8b3310>,).
# 2017-02-17 11:35:21,785 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0037.fits
# 2017-02-17 11:35:21,903 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-02-17 11:35:21,992 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = OLS
# 2017-02-17 11:35:21,993 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = unweighted
# 2017-02-17 11:35:22,004 - stpipe.SloperPipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full((3, 1024, 1032), 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
#
# 2017-02-17 11:38:28,666 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 27.10528
# 2017-02-17 11:38:29,079 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 30
# 2017-02-17 11:38:29,080 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 3
# 2017-02-17 11:38:29,282 - stpipe.SloperPipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/astropy/utils/decorators.py:470: AstropyDeprecationWarning: "clobber" was deprecated in version 1.3 and will be removed in a future version. Use argument "overwrite" instead.
#   AstropyDeprecationWarning)
#
# 2017-02-17 11:38:29,286 - stpipe.SloperPipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/astropy/io/fits/card.py:976: VerifyWarning: Card is too long, comment will be truncated.
#   VerifyWarning)
#
# 2017-02-17 11:38:29,407 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-02-17 11:38:29,408 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-02-17 11:38:29,416 - stpipe.SloperPipeline - INFO - Saving file /Users/patrickkavanagh/tutorials page/notebooks/MRS_pipeline/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2017-02-17 11:38:29,511 - stpipe.SloperPipeline - INFO - Step SloperPipeline done

# %% [markdown]
# #### quick check of output

# %%
# set the new level 2A filename
level2A_file = input_basename + '_rate.fits'

# open the level 2A file using astropy fits
with fits.open(level2A_file) as hdulist:

    # print extension table info
    hdulist.info()

    # check the status of each 2A calibration step
    print ""
    print 'Status of 2A calibration steps in output header:'
    stepsCheck = ['S_DQINIT', 'S_SATURA', 'S_IPC', 'S_REFPIX', 'S_RSCD', 'S_LASTFR', 'S_LINEAR', 'S_DARK', 'S_PERSIS', 'S_JUMP', 'S_RAMP']
    for key in stepsCheck:
        print key + ': ' + hdulist[0].header[key]
# Out:
# Filename: det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     174   ()
#   1  SCI         ImageHDU         9   (1032, 1024)   float32
#   2  DQ          ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   3  ERR         ImageHDU         8   (1032, 1024)   float32
#   4  ASDF        ImageHDU         7   (4651,)   uint8
#
# Status of 2A calibration steps in output header:
# S_DQINIT: COMPLETE
# S_SATURA: COMPLETE
# S_IPC: COMPLETE
# S_REFPIX: COMPLETE
# S_RSCD: COMPLETE
# S_LASTFR: COMPLETE
# S_LINEAR: COMPLETE
# S_DARK: COMPLETE
# S_PERSIS: SKIPPED
# S_JUMP: COMPLETE
# S_RAMP: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Spec2Pipeline
print Spec2Pipeline.__doc__
# Out:
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, photom, resample_spec,
#     cube_build, and extract_1d.

# %% [markdown]
# For the MRS, the level 2B steps in order are: assign_wcs, bkg_subtract, flat_field, srctype, straylight, fringe, photom, cube_build, extract_1d
#
# Note that bkg_subtract requires an association so will not be applied to single files. srctype specifies whether the source is point like or extended. In Build 7, this simply writes the source type keyword without applying an algorithm to make the decision.

# %% [markdown]
# #### run pipeline

# %%
Spec2Pipeline.call(level2A_file, output_file='%s_cal.fits' % input_basename)
# Out:
# 2017-02-17 11:52:42,993 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2017-02-17 11:52:42,994 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2017-02-17 11:52:42,997 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-02-17 11:52:42,999 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2017-02-17 11:52:43,001 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-02-17 11:52:43,004 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-02-17 11:52:43,006 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-02-17 11:52:43,008 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2017-02-17 11:52:43,009 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2017-02-17 11:52:43,011 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2017-02-17 11:52:43,012 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2017-02-17 11:52:43,014 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-02-17 11:52:43,016 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2017-02-17 11:52:43,017 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-02-17 11:52:44,243 - stpipe.Spec2Pipeline.pathloss - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2017-02-17 11:52:44,733 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-02-17 11:52:44,734 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-02-17 11:52:44,735 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-02-17 11:52:44,736 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0016.asdf'.
# 2017-02-17 11:52:44,737 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-02-17 11:52:44,737 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-02-17 11:52:44,738 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-02-17 11:52:44,739 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-02-17 11:52:44,740 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-02-17 11:52:44,741 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-02-17 11:52:44,741 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-02-17 11:52:44,742 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-02-17 11:52:44,743 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0009.asdf'.
# 2017-02-17 11:52:44,744 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0009.asdf'.
# 2017-02-17 11:52:44,745 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_v2v3_0009.asdf'.
# 2017-02-17 11:52:44,746 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0002.asdf'.
# 2017-02-17 11:52:45,357 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-02-17 11:52:45,358 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0016.fits'.
# 2017-02-17 11:52:45,854 - stpipe.Spec2Pipeline.resample_spec - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2017-02-17 11:52:46,474 - stpipe.Spec2Pipeline.straylight - INFO - Prefetch for STRAYMASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_straymask_0006.fits'.
# 2017-02-17 11:52:47,191 - stpipe.Spec2Pipeline.fringe - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0024.fits'.
# 2017-02-17 11:52:47,929 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-02-17 11:52:48,051 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2017-02-17 11:52:48,051 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2017-02-17 11:52:48,791 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-02-17 11:52:48,792 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-02-17 11:52:48,793 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-02-17 11:52:48,794 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0016.asdf'.
# 2017-02-17 11:52:48,795 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-02-17 11:52:48,796 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-02-17 11:52:48,797 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-02-17 11:52:48,798 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-02-17 11:52:48,798 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-02-17 11:52:48,799 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-02-17 11:52:48,800 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-02-17 11:52:48,801 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-02-17 11:52:48,802 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0009.asdf'.
# 2017-02-17 11:52:48,803 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0009.asdf'.
# 2017-02-17 11:52:48,804 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_v2v3_0009.asdf'.
# 2017-02-17 11:52:48,804 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0002.asdf'.
# 2017-02-17 11:52:48,864 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x1877cb5d0>,).
# 2017-02-17 11:52:57,781 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-02-17 11:52:58,189 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-02-17 11:52:58,451 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x18fe9a650>,).
# 2017-02-17 11:53:01,334 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-17 11:53:02,574 - stpipe.Spec2Pipeline.flat_field - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/flatfield/flat_field.py:185: RuntimeWarning: divide by zero encountered in true_divide
#   science.data /= flat_data
#
# 2017-02-17 11:53:02,780 - stpipe.Spec2Pipeline.flat_field - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/flatfield/flat_field.py:186: RuntimeWarning: divide by zero encountered in true_divide
#   science.err /= flat_data
#
# 2017-02-17 11:53:03,664 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2017-02-17 11:53:03,960 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x25c612290>,).
# 2017-02-17 11:53:05,161 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of EXTENDED
# 2017-02-17 11:53:05,564 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2017-02-17 11:53:08,258 - stpipe.Spec2Pipeline.straylight - INFO - Prefetch for STRAYMASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_straymask_0006.fits'.
# 2017-02-17 11:53:08,352 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.image.ImageModel object at 0x19010f750>,).
# 2017-02-17 11:53:10,996 - stpipe.Spec2Pipeline.straylight - INFO - Using STRAYLIGHT reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_straymask_0006.fits
# 2017-02-17 11:53:20,942 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2017-02-17 11:53:23,658 - stpipe.Spec2Pipeline.fringe - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0024.fits'.
# 2017-02-17 11:53:23,750 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.image.ImageModel object at 0x187352890>,).
# 2017-02-17 11:53:26,411 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0024.fits
# 2017-02-17 11:53:26,554 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-17 11:53:26,555 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-17 11:53:26,556 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-17 11:53:27,797 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2017-02-17 11:53:28,197 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2017-02-17 11:53:30,952 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-02-17 11:53:30,953 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0016.fits'.
# 2017-02-17 11:53:31,040 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x1878bedd0>,).
# 2017-02-17 11:53:33,683 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0016.fits
# 2017-02-17 11:53:35,185 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2017-02-17 11:53:35,495 - stpipe.Spec2Pipeline.photom - INFO - Relative response table written.
# 2017-02-17 11:53:35,496 - stpipe.Spec2Pipeline.photom - INFO - Writing PHOTMJSR with value: 1e-05
# 2017-02-17 11:53:35,983 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2017-02-17 11:53:38,379 - stpipe.Spec2Pipeline - INFO - Saved calibrated product to det_image_seq1_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2017-02-17 11:53:38,654 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.image.ImageModel object at 0x18fdfbf90>,).
# 2017-02-17 11:53:38,655 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2017-02-17 11:53:38,656 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2017-02-17 11:53:38,656 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2017-02-17 11:53:38,657 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: standard
# 2017-02-17 11:53:38,658 - stpipe.Spec2Pipeline.cube_build - INFO - Output Base det_image_seq1_MIRIFUSHORT_12SHORTexp1_cal
# 2017-02-17 11:53:39,890 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2017-02-17 11:53:39,891 - stpipe.Spec2Pipeline.cube_build - INFO - The desried cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2017-02-17 11:53:39,892 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2017-02-17 11:53:39,893 - stpipe.Spec2Pipeline.cube_build - INFO - Working on data  from 1,SHORT
# 2017-02-17 11:53:41,599 - stpipe.Spec2Pipeline.cube_build - INFO - Time find foot print = 0.4.s
# 2017-02-17 11:53:41,599 - stpipe.Spec2Pipeline.cube_build - INFO - Working on data  from 2,SHORT
# 2017-02-17 11:53:43,155 - stpipe.Spec2Pipeline.cube_build - INFO - Time find foot print = 0.3.s
# 2017-02-17 11:53:43,158 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2017-02-17 11:53:43,159 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-02-17 11:53:43,160 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    34  17.00   0.00002334   0.17200100  -2.76955618   2.76955623
# 2017-02-17 11:53:43,162 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    30  15.00  -0.04718046   0.17720418  -2.63926106   2.63926103
# 2017-02-17 11:53:43,162 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4632   1.00   4.84693010   0.00086975   4.84693010   8.87561210
# 2017-02-17 11:53:43,163 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel: 1
# 2017-02-17 11:53:43,165 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel: 2
# 2017-02-17 11:53:43,166 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers subchannel: SHORT
# 2017-02-17 11:53:43,166 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers subchannel: SHORT
# 2017-02-17 11:53:43,432 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest 0.172001 0.177204 0.000870
# 2017-02-17 11:53:43,433 - stpipe.Spec2Pipeline.cube_build - INFO - Power parameters for weighting   1.0   1.0   1.0
# 2017-02-17 11:54:08,500 - stpipe.Spec2Pipeline.cube_build - INFO - Working on Band defined by:1 SHORT
# 2017-02-17 11:54:08,501 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files in cube 1
# 2017-02-17 11:54:10,327 - stpipe.Spec2Pipeline.cube_build - INFO - Working on Band defined by:2 SHORT
# 2017-02-17 11:54:10,328 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files in cube 1
# 2017-02-17 11:54:12,194 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 3.7.s
# 2017-02-17 11:54:12,195 - stpipe.Spec2Pipeline.cube_build - INFO - number of elements in PT 847006
# 2017-02-17 11:54:51,908 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find the ROI = 39.7.s
# 2017-02-17 11:55:06,004 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/cube_build/cube_build.py:596: RuntimeWarning: invalid value encountered in double_scalars
#   value = value + weightpt[j] * pixelflux[j]
#
# 2017-02-17 11:55:06,143 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 14.2.s
# 2017-02-17 11:55:06,144 - stpipe.Spec2Pipeline.cube_build - INFO - Time find Cube Flux= 14.2.s
# 2017-02-17 11:55:11,050 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2017-02-17 11:55:11,122 - stpipe.Spec2Pipeline - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/datamodels/fits_support.py:305: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if instance in ('N/A', '#TODO', '', None):
#
# 2017-02-17 11:55:11,400 - stpipe.Spec2Pipeline - INFO - Saved IFU cube product to det_image_seq1_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2017-02-17 11:55:12,239 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-02-17 11:55:12,348 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.ifucube.IFUCubeModel object at 0x191cde950>,).
# 2017-02-17 11:55:12,969 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2017-02-17 11:55:13,034 - stpipe.Spec2Pipeline.extract_1d - WARNING - source_type was 'EXTENDED', setting to 'point'.
# 2017-02-17 11:55:13,034 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2017-02-17 11:55:14,162 - stpipe.Spec2Pipeline.extract_1d - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/photutils/aperture/core.py:413: RuntimeWarning: invalid value encountered in multiply
#   aperture_sums.append(np.sum(data_cutout * mask.data))
#
# 2017-02-17 11:55:27,008 - stpipe.Spec2Pipeline.extract_1d - WARNING - No relsens for input file.
# 2017-02-17 11:55:27,119 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-02-17 11:55:27,241 - stpipe.Spec2Pipeline - INFO - Saved extracted spectrum to det_image_seq1_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2017-02-17 11:55:27,242 - stpipe.Spec2Pipeline - INFO - ... ending calwebb_spec2
# 2017-02-17 11:55:27,243 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# ### check of output
#
# The level 2B pipeline for the MRS produces three files:
#
# _cal.fits - the calibrated level 2B file
#
# _s3d.fits - the cube
#
# _x1d.fits - the 1d spectrum
#
# We can have a look at each of these

# %%
# set the output file names
level2B_file = input_basename + '_cal.fits'
cube_file = input_basename + '_s3d.fits'
spec_file = input_basename + '_x1d.fits'

# %% [markdown]
# #### level 2B file

# %%
# open the level 2B file using astropy fits
with fits.open(level2B_file) as hdulist:

    # print extension table info
    hdulist.info()

    # check the status of each 2A calibration step
    print ""
    print 'Status of calibration steps in output header:'
    stepsCheck = ['S_WCS', 'S_FLAT', 'S_STRAY', 'S_FRINGE', 'S_PHOTOM']
    for key in stepsCheck:
        print key + ': ' + hdulist[0].header[key]
# Out:
# Filename: det_image_seq1_MIRIFUSHORT_12SHORTexp1_cal.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     273   ()
#   1  SCI         ImageHDU         9   (1032, 1024)   float32
#   2  DQ          ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   3  ERR         ImageHDU         8   (1032, 1024)   float32
#   4  RELSENS     BinTableHDU     13   21R x 2C   [D, D]
#   5  ASDF        ImageHDU         7   (8696562,)   uint8
#
# Status of calibration steps in output header:
# S_WCS: COMPLETE
# S_FLAT: COMPLETE
# S_STRAY: COMPLETE
# S_FRINGE: COMPLETE
# S_PHOTOM: COMPLETE

# %% [markdown]
# #### calibrated image

# %%
from jwst import datamodels
from matplotlib.colors import LogNorm

# open the input image as a jwst data model
with datamodels.open(input_file) as in_dm:
        
    # open the calibrated image as a jwst data model
    with datamodels.open(level2B_file) as im_dm:

        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image. Note the user may have to adjust
        # the scale parameters
        # %matplotlib notebook
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_axis_bgcolor('black')
        axs[1].imshow(im_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=20)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_axis_bgcolor('black')

        plt.tight_layout()
        plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# #### cube file

# %%
from matplotlib.colors import LogNorm

# open the cube as a jwst data model
with datamodels.open(cube_file) as cube_dm:
    
    # split the wavelength direction in two
    # to separate each channel
    cube_divide = cube_dm.data.shape[0] / 2
    
    # plot--------------------------------------
    # sum the frames each half of the channel
    # divide for the first integration and plot
    # exclude edges of channels to avoid spaxels
    # Note the user may have to adjust the scaling
    # parameters
    # %matplotlib notebook
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    axs[0].imshow(np.sum(cube_dm.data[1000:cube_divide-1000], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=50,vmax=500))
    axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_axis_bgcolor('black')
    axs[1].imshow(np.sum(cube_dm.data[cube_divide+1000:-1000], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=100,vmax=3e4))
    axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_axis_bgcolor('black')
    
    plt.tight_layout()
    plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# #### 1D spectrum
#
# #### Note that the flux units produced by the pipeline step extract_1d are not correct. How flux calibration is applied in the pipeline is still a work in progress (see Pipeline issues page).

# %%
from jwst.datamodels import SpecModel

# open the spectrum as a jwst data model
with SpecModel(spec_file) as spec_dm:

    # plot--------------------------------------
    # simple XY plot of the spectrum
    # %matplotlib notebook
    fig, axs = plt.subplots(1, 2, figsize=(13, 5))

    # plot the spectrum in the channel 2 wavelength range
    axs[0].plot(spec_dm.spec_table['WAVELENGTH'], spec_dm.spec_table['FLUX'], c='b', marker='.', markersize=5, linestyle='-', linewidth=2)
    axs[0].set_ylabel(r'Flux units')
    axs[0].set_xlabel(r'Wavelength ($\mu$m)')
    axs[0].set_ylim(10,250)
    axs[0].set_xlim(4.9,5.7)
    axs[0].annotate('Short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

    
    axs[1].plot(spec_dm.spec_table['WAVELENGTH'], spec_dm.spec_table['FLUX'], c='b', marker='.', markersize=5, linestyle='-', linewidth=2)
    axs[1].set_ylabel(r'Flux units')
    axs[1].set_xlabel(r'Wavelength ($\mu$m)')
    axs[1].set_ylim(300,1000)
    axs[1].set_xlim(7.5,8.7)
    axs[1].annotate('Long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')


    plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# That's it! You can now run these products through your analysis procedures.
